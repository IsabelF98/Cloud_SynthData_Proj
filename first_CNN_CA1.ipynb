# %% [markdown]
# # First Model for New Data
#
# August 22, 2024

# %%
import sys
import os

myhost = os.uname()[1]
print("Running on Computer: [%s]" %myhost)

sys.path.insert(0, '/home/ifernand/Code/') 
dirname = '/home/ifernand/Cloud_SynthData_Proj'

import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
from scipy import io as sio
import torch
import time
import h5py

# NDN tools
import NDNT
import NDNT.utils as utils
from NDNT.modules.layers import *
from NDNT.networks import *
import NDNT.NDN as NDN
from NTdatasets.conway.synthcloud_datasets import SimCloudData
from NTdatasets.generic import GenericDataset
from ColorDataUtils.multidata_utils import MultiExperiment
import ColorDataUtils.ConwayUtils as CU
from ColorDataUtils import readout_fit
from ColorDataUtils.simproj_utils import *
from NDNT.utils import fit_lbfgs, fit_lbfgs_batch
from NDNT.utils import imagesc   
from NDNT.utils import ss

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device0 = torch.device("cpu")
dtype = torch.float32

# %load_ext autoreload
# %autoreload 2
# Out:
# Running on Computer: [ca1]
# Invoking __init__.py for NDNT.utils

# %% [markdown]
# ## Load Data

# %%
out_file = 'data/cloud_data_stim_dim120_robs_sqrad_0.3.hdf5' #'data/cloud_data_stim_dim80_robs_sqrad_0.1.hdf5'
with h5py.File(out_file, 'r') as f:
    x_pos = f['x_pos'][:]
    y_pos = f['y_pos'][:]
    cell_key = [str(f['cell_key'][:][i], encoding='utf-8') for i in range(x_pos.shape[0])]
    file_start_pos = list(f['file_start_pos'][:])

# %%
# cell specific indices
LGN_idx = [i for i, val in enumerate(cell_key) if val == 'X_ON' or val == 'X_OFF']
V1_idx  = [i for i, val in enumerate(cell_key) if val == 'V1_Exc_L4' or val == 'V1_Inh_L4' or val == 'V1_Exc_L2/3' or val == 'V1_Inh_L2/3']
L4_idx  = [i for i, val in enumerate(cell_key) if val == 'V1_Exc_L4' or val == 'V1_Inh_L4']
print('LGN cells:', len(LGN_idx))
print('V1 cells:', len(V1_idx))
print('L4 cells:', len(L4_idx))
# Out:
# LGN cells: 214
# V1 cells: 1491
# L4 cells: 794

# %%
V1_cell_key = [cell_key[i] for i in V1_idx]
L23_exc_idx = [i for i, val in enumerate(V1_cell_key) if val == 'V1_Exc_L2/3']
L23_inh_idx = [i for i, val in enumerate(V1_cell_key) if val == 'V1_Inh_L2/3']
L4_exc_idx = [i for i, val in enumerate(V1_cell_key) if val == 'V1_Exc_L4']
L4_inh_idx = [i for i, val in enumerate(V1_cell_key) if val == 'V1_Inh_L4']

# %% [markdown]
# ## Data Class

# %%
#out_file = 'data/cloud_data_stim_dim120_robs_sqrad_0.3.hdf5'
start    = time.time()
data     = SimCloudData(file_name=out_file, down_sample=2, cell_idx=V1_idx, num_lags=11)
end      = time.time()
print('CPU Time', end-start, 'sec')
# Out:
# CPU Time 69.58485007286072 sec

# %%
stim_dims = data.stim_dims
num_lags = data.num_lags
L  = stim_dims[1]
print('stim_dims =', stim_dims)
print('num_lags =', num_lags)
print('L =', L)
# Out:
# stim_dims = [1, 60, 60, 1]
# num_lags = 11
# L = 60

# %%
NC = data[0]['robs'].shape[1]
print('Number of cells', NC)
# Out:
# Number of cells 1491

# %%
NT = data.NT
print('Number of time points', NT)
# Out:
# Number of time points 510000

# %%
pxl_x_pos, pxl_y_pos = deg2pxl(x_pos[V1_idx], y_pos[V1_idx], L, down_sample=2)
mu0s = utils.pixel2grid(np.stack((pxl_x_pos,pxl_y_pos),axis=1), L=L)
print('Spatial mu0:', mu0s.shape)
# Out:
# Spatial mu0: (1491, 2)

# %%
# Adam Parameters
adam_pars = utils.create_optimizer_params(
    optimizer_type='AdamW', batch_size=3,
    learning_rate=0.01, early_stopping_patience=4,
    optimize_graph=False, weight_decay=0.2, accumulated_grad_batches=3)
adam_pars['device'] = device

# %% [markdown]
# ## STA

# %%
robs = data[:]['robs'][:,:10]*data[:]['dfs'][:,:10]
nspks = torch.sum(robs,axis=0)

# %%
sta_arr = np.zeros((4,L,L,10))
for j in range(4):
    if j == 0:
        sta = (data[:]['stim'].T @ robs)
    else:
        sta = (data[:]['stim'][:-j, ...].T @ robs[j:,:])
    sta_arr[j,:,:,:] = (sta/nspks).reshape([L,L,10]).numpy() #.detach().cpu().numpy()

# %%
cc = 10
ss(cc,4)
k = 1
for i in range(cc):
    for j in range(4):
        plt.subplot(cc,4,k)
        imagesc(sta_arr[j,:,:,i])
        plt.title('cell '+str(i)+' lag '+str(j))
        k += 1
plt.tight_layout()
plt.show()

# %%
# TO DO: change to pixle space
V1_y_pos = (x_pos[V1_idx]*10)+L//2
V1_x_pos = -1*((y_pos[V1_idx]*10)+L//2)+L
V1_ori   = ori[V1_idx]

# %%
ss(4,5)
k = 1
for i in range(20):
    plt.subplot(4,5,i+1)
    imagesc(sta_arr[2,:,:,i])
    plt.scatter(V1_x_pos[i],V1_y_pos[i],c='r',s=40,marker='+')
    plt.title('cell '+str(i)+' ori '+str(np.round((180/np.pi)*V1_ori[i])))
plt.tight_layout()

# %% [markdown]
# ## GLM

# %%
Treg = 1
Xreg = 10000.0
L1reg = 1.0
GLreg = 10.0

glm_par = Tlayer.layer_dict( 
    input_dims=data.stim_dims, num_filters=NC, bias=True, num_lags=data.num_lags, norm_type=0,
    NLtype='softplus', initialize_center=True)
glm_par['reg_vals'] = {'d2x': Xreg, 'd2t': Treg, 'l1': L1reg, 'glocalx': GLreg,'edge_t':10} 

glm = NDN( layer_list=[glm_par], loss_type='poisson')
glm.list_parameters()
# Out:
# Network 0:
#   Layer 0:
#       weight: torch.Size([43200, 10])
#       bias: torch.Size([10])

# %%
glm = glm.to(device)
fit_lbfgs(glm, data[:], verbose=True)
glm = glm.to(device0)
# Out:
# Iteration: 0 | Loss: 0.8419547080993652
# Iteration: 1 | Loss: 0.8403301239013672
# Iteration: 1 | Loss: 0.8261598348617554
# Iteration: 1 | Loss: 0.7287380695343018
# Iteration: 2 | Loss: 0.6762744188308716
# Iteration: 126 | Loss: 0.20244573056697845
# Iteration: 127 | Loss: 0.2024456113576889
# Iteration: 128 | Loss: 0.2024453729391098
# Iteration: 129 | Loss: 0.2024451494216919
# Iteration: 130 | Loss: 0.20244498550891876
# Iteration: 131 | Loss: 0.2024449110031128

# %%
w_glm = glm.get_weights()
print(w_glm.shape)
# Out:
# (60, 60, 12, 10)

# %%
ss(5,12)
k = 1
for i in range(5):
    for j in range(12):
        plt.subplot(5,12,k)
        imagesc(w_glm[:,:,j,i])
        plt.scatter(pxl_x_pos[V1_idx][i],pxl_x_pos[V1_idx][i],c='r',s=40,marker='+')
        plt.title('cell '+str(i)+' lag '+str(j))
        k += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ori CNN

# %%
# LGN layer reg
Xreg0 = 1.0 # d2/dx
Creg0 = 0.05 # center
Treg = 1
#LGNwidth = LGN_filt.shape[0]

# Proj layer — still playing around with these
Xreg1 = 0.001 # d2/dx
Creg1 = 0.001 # center

ORIreg = 0 # chose orientation over spacial dim

# Define convolutional layers in the deep network
num_subs = [8,8,8] # num sub-units per layer
fws = [19,9,9]  # filter widths for each layer 
angles = [0,30,60,90,120,150] # [0,45,90,135]

# LGN layer
clayers = [STconvLayer.layer_dict( 
    input_dims=data.stim_dims, num_filters=2, bias=False, norm_type=1, 
    filter_dims=[1,19,19,num_lags], NLtype='relu', initialize_center=True,
    reg_vals={'d2t':Treg, 'edge_t': 100, 'd2x':Xreg0, 'center': Creg0} )]

# Projection Layer
clayers.append(OriConvLayer.layer_dict(
    num_filters=num_subs[0], num_inh=num_subs[0]//4,
    bias=False, norm_type=1, initialize_center=True, window='hamming',
    filter_width=fws[0], NLtype='relu', reg_vals={'d2x':Xreg1, 'center': Creg1},
    angles=angles))

# Rest
for ii in range(1,len(fws)):
    clayers.append(OriConvLayer.layer_dict( 
        num_filters=num_subs[ii], num_inh=num_subs[ii]//4, bias=False, norm_type=1, 
        filter_width=fws[ii], NLtype='relu',
        output_norm='batch', initialize_center=True, #window='hamming', 
        angles=angles) )
        
scaffold_net =  FFnetwork.ffnet_dict(
    ffnet_type='scaffold3d', xstim_n='stim', layer_list=clayers, scaffold_levels=[1,2,3], num_lags_out=len(angles))

readout_pars = ReadoutLayerQsample.layer_dict(
    num_filters=NC, NLtype='softplus', bias=True, pos_constraint=True,
    reg_vals={'gmax_t': None})

readout_net = FFnetwork.ffnet_dict( 
    xstim_n = None, ffnet_n=[0],
    layer_list = [readout_pars], ffnet_type='readout')

cnn = NDN(ffnet_list = [scaffold_net, readout_net], loss_type='poisson')

#cnn.networks[0].layers[0].weight.data = LGN_filt.reshape((LGNwidth**2,2))  # this it the LGN from before
#cnn.networks[0].layers[0].set_parameters(val=True)

cnn.networks[1].layers[0].mu.data[:,0] = torch.tensor( mu0s[:,0], dtype=torch.float32)
cnn.networks[1].layers[0].mu.data[:,1] = torch.tensor( mu0s[:,1], dtype=torch.float32)
cnn.networks[1].layers[0].fit_mus(True)
cnn.networks[1].layers[0].fit_Qmus(True)

cnn.block_sample = True
cnn.list_parameters()
# Out:
#   ReadoutLayer: fitting mus
#   ReadoutLayer: fitting Qmus
# Network 0:
#   Layer 0:
#       weight: torch.Size([4332, 2])
#   Layer 1:
#       weight: torch.Size([722, 8])
#   Layer 2:
#       weight: torch.Size([648, 8])
#   Layer 3:
#       weight: torch.Size([648, 8])
# Network 1:
#   Layer 0:
#       weight: torch.Size([24, 1491])
#       bias: torch.Size([1491])
#       mu: torch.Size([1491, 2])
#       sigma: torch.Size([1491, 1])
#       Qmu: torch.Size([1491, 1])
#       Qsigma: torch.Size([1491, 1])

# %%
#cnn = cnn.to(device)
cnn.fit(data, **adam_pars, verbose=2)
#cnn = cnn.to(device0)
# Out:
# Model: M491_CsXXX_X
#
# GPU Available: True, GPU Used: True
# Epoch 1: 100%|███████████████████████████████████████████████████████| 408/408 [08:36<00:00,  1.27s/it, train_loss=0.35692]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:51<00:00,  1.96it/s, val_loss=0.320491]
# Epoch 2: 100%|██████████████████████████████████████████████████████| 408/408 [08:36<00:00,  1.27s/it, train_loss=0.319975]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:51<00:00,  1.97it/s, val_loss=0.303044]
# Epoch 3: 100%|██████████████████████████████████████████████████████| 408/408 [08:34<00:00,  1.26s/it, train_loss=0.309574]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:52<00:00,  1.96it/s, val_loss=0.297026]
# Epoch 4: 100%|██████████████████████████████████████████████████████| 408/408 [08:48<00:00,  1.30s/it, train_loss=0.307009]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:49<00:00,  2.05it/s, val_loss=0.298959]
# Epoch 5: 100%|██████████████████████████████████████████████████████| 408/408 [08:34<00:00,  1.26s/it, train_loss=0.306311]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:49<00:00,  2.06it/s, val_loss=0.298242]
# Epoch 6: 100%|██████████████████████████████████████████████████████| 408/408 [08:35<00:00,  1.26s/it, train_loss=0.305371]
# Validating ver=20: 100%|███████████████████████████████████████████████| 102/102 [00:51<00:00,  1.97it/s, val_loss=0.29589]
# Epoch 7: 100%|███████████████████████████████████████████████████████| 408/408 [08:35<00:00,  1.26s/it, train_loss=0.30492]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:49<00:00,  2.07it/s, val_loss=0.292928]
# Epoch 8: 100%|██████████████████████████████████████████████████████| 408/408 [08:34<00:00,  1.26s/it, train_loss=0.304727]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:49<00:00,  2.07it/s, val_loss=0.295332]
# Epoch 9: 100%|██████████████████████████████████████████████████████| 408/408 [08:35<00:00,  1.26s/it, train_loss=0.304382]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:51<00:00,  1.98it/s, val_loss=0.296816]
# Epoch 10: 100%|█████████████████████████████████████████████████████| 408/408 [08:35<00:00,  1.26s/it, train_loss=0.304016]
# Validating ver=20: 100%|██████████████████████████████████████████████| 102/102 [00:51<00:00,  1.99it/s, val_loss=0.295304]
# Epoch 11:   7%|███▊                                                  | 29/408 [00:36<08:03,  1.28s/it, train_loss=0.302408]
# Done fitting
#   Fit complete: 5713.0190143585205 sec elapsed

# %%
cnn.save_model_zip('models/0916_four_layer_model.ndn')
# Out:
#   Model saved:  models/0916_four_layer_model.ndn

# %%
cnn = NDN.load_model_zip('models/first_model_test_NLL.ndn')
cnn.block_sample = True

# %%
LL = cnn.eval_models(data, data_inds=data.val_blks, device=device, batch_size=2, null_adjusted=True)
print('Log Likelyhood shape', LL.shape)
# Out:
# Eval models: 100%|█████████████████████████████████████████████████████████████████████████| 51/51 [00:05<00:00,  8.72it/s]
# Log Likelyhood shape (1491,)

# %%
print('Mean LL:', np.mean(LL), 'L23 Exc LL:', np.mean(LL[L23_exc_idx]), 'L23 Inh LL:', np.mean(LL[L23_inh_idx]), 
      'L4 Exc LL:', np.mean(LL[L4_exc_idx]), 'L4 Inh LL:', np.mean(LL[L4_inh_idx]))
ss()
plt.plot([0,NC],[0,0], 'k')
plt.plot(LL)
plt.xlim([0,NC])
plt.show()
# Out:
# Median LL: 0.38476136

# %%
cnn.plot_filters()

# %%
ori_filters1 = cnn.get_weights(ffnet_target=0,layer_target=1)
ei_mask = deepcopy(cnn.networks[0].layers[1]._ei_mask)
print(ori_filters1.shape)
print(ei_mask.shape)
# Out:
# (2, 19, 19, 8)
# torch.Size([48])

# %%
ss(2,4)
for i in range(8):
    plt.subplot(2,4,i+1)
    imagesc(ori_filters1[0,:,:,i])
plt.tight_layout()
plt.show()

# %%
ori_filters2 = cnn.get_weights(ffnet_target=0,layer_target=2)
print(ori_filters2.shape)
# Out:
# (8, 9, 9, 8)

# %%
ss(2,4)
for i in range(8):
    plt.subplot(2,4,i+1)
    imagesc(ori_filters2[0,:,:,i])
plt.tight_layout()
plt.show()

# %%
sig = deepcopy(cnn.networks[1].layers[0].sigma.data).numpy()
Qsig = deepcopy(cnn.networks[1].layers[0].Qsigma.data).numpy()

# %%
ss()
plt.plot(sig)

# %%
ss()
plt.plot(Qsig)

# %%
Qmu = deepcopy(cnn.networks[1].layers[0].Qmu.data).numpy()

# %%
ss()
plt.plot(Qmu)

# %%
cnn_preds = cnn(data[:10]).detach().cpu().numpy()

# %%
ss()
plt.plot(cnn_preds[:,0],label='pred',alpha=0.5)
plt.plot(data[:10]['robs'][:,0],label='true',alpha=0.5)
plt.legend()

# %%
ss()
plt.plot(cnn_preds[:,-1],label='pred',alpha=0.5)
plt.plot(data[:10]['robs'][:,-1],label='true',alpha=0.5)
plt.legend()

# %% [markdown]
# ## Non-Ori CNN

# %%
Treg = 1

# LGN layer reg
Xreg0 = 1.0 # d2/dx
Creg0 = 0.05 # center

# Proj layer reg
Xreg1 = 0.001 # d2/dx
Creg1 = 0.001 # center 

# LGN layer
clayers = [STconvLayer.layer_dict( 
    input_dims=data.stim_dims, num_filters=2, bias=False, norm_type=1, 
    filter_dims=[1,19,19,10], NLtype='relu', initialize_center=True,
    reg_vals={'d2t':Treg, 'edge_t': 100, 'd2x':Xreg0, 'center': Creg0} )]

# Projection Layer
clayers.append(ConvLayer.layer_dict(
    num_filters=14, num_inh=14//2,
    bias=False, norm_type=1, initialize_center=True, window='hamming',
    filter_dims=19, NLtype='relu', reg_vals={'d2x':Xreg1, 'center': Creg1}))
    #reg_vals={'d2t':Treg, 'edge_t': 100, 'd2x':Xreg1, 'center': Creg1}))

# Time Layer w/ mask
clayers.append(MaskSTconvLayer.layer_dict(
    num_filters=20, num_inh=20//2,
    bias=False, norm_type=1, initialize_center=True, window='hamming',
    filter_dims=[14,5,5,2], NLtype='relu', #reg_vals={'d2x':Xreg1, 'center': Creg1}))
    reg_vals={'d2t':Treg, 'edge_t': 100}))

clayers.append(ConvLayer.layer_dict(
    num_filters=10, num_inh=10//2,
    bias=False, norm_type=1, initialize_center=True, window='hamming',
    filter_dims=9, NLtype='relu'))

scaffold_net =  FFnetwork.ffnet_dict(
    ffnet_type='scaffold', xstim_n='stim', layer_list=clayers, scaffold_levels=[1,2,3])

readout_pars = ReadoutLayer.layer_dict(
    num_filters=NC, NLtype='softplus', bias=True, pos_constraint=True,
    reg_vals={'max': 0.1})

readout_net = FFnetwork.ffnet_dict( 
    xstim_n = None, ffnet_n=[0],
    layer_list = [readout_pars], ffnet_type='readout')

cnn = NDN(ffnet_list = [scaffold_net, readout_net], loss_type='poisson')

mask = torch.ones(cnn.get_weights(ffnet_target=0,layer_target=2).shape, dtype=torch.float32)
mask[:,:,:,1,:] = 0
cnn.networks[0].layers[2].mask = mask.reshape(cnn.networks[0].layers[2].weight.data.shape)

cnn.networks[1].layers[0].mu.data[:,0] = torch.tensor( mu0s[:,0], dtype=torch.float32)
cnn.networks[1].layers[0].mu.data[:,1] = torch.tensor( mu0s[:,1], dtype=torch.float32)
cnn.networks[1].layers[0].fit_mus(True)

cnn.block_sample = True
cnn.list_parameters()
# Out:
#   ReadoutLayer: fitting mus
# Network 0:
#   Layer 0:
#       weight: torch.Size([3610, 2])
#   Layer 1:
#       weight: torch.Size([722, 14])
#   Layer 2:
#       weight: torch.Size([700, 20])
#   Layer 3:
#       weight: torch.Size([1620, 10])
# Network 1:
#   Layer 0:
#       weight: torch.Size([44, 1491])
#       bias: torch.Size([1491])
#       mu: torch.Size([1491, 2])
#       sigma: torch.Size([1491, 1])

# %%
cnn.fit(data, **adam_pars, verbose=2)
# Out:
# Model: M491_CsCXC_R
#
# GPU Available: True, GPU Used: True
# Epoch 1: 100%|███████████| 136/136 [01:57<00:00,  1.16it/s, train_loss=0.437012]
# Validating ver=1: 100%|██████| 34/34 [00:08<00:00,  4

# Validating ver=1: 100%|██████| 34/34 [00:08<00:00,  4.09it/s, val_loss=0.304995]
# Epoch 22: 100%|██████████| 136/136 [01:56<00:00,  1.17it/s, train_loss=0.309185]
# Validating ver=1: 100%|██████| 34/34 [00:08<00:00,  4.07it/s, val_loss=0.307766]
# Epoch 23: 100%|██████████| 136/136 [01:55<00:00,  1.17it/s, train_loss=0.310631]
# Validating ver=1: 100%|██████| 34/34 [00:08<00:00,  4.13it/s, val_loss=0.309937]
# Early stopping
# Done fitting
#   Fit complete: 2861.5145757198334 sec elapsed

# %%
cnn.save_model_zip('models/0927_three_layer_model_non-ori_CNN_V1_timemask.ndn')
# Out:
#   Model saved:  models/0925_three_layer_model_non-ori_CNN_V1_timemask.ndn

# %%
cnn = NDN.load_model_zip('models/0920_two_layer_model_non-ori_CNN_L4_10lag+1.ndn')
cnn.block_sample = True
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cnn = NDN.load_model_zip('models/0920_two_layer_model_non-ori_CNN_L4_10lag+1.ndn')
#       2 cnn.block_sample = True
#
# File ~/Code/NDNT/NDN.py:1507, in NDN.load_model_zip(cls, path)
#    1504 temp_name = os.path.join(temp_dir, file_name)
#    1506 # open the zip file
# -> 1507 with zipfile.ZipFile(path, 'r') as myzip:
#    1508     myzip.extractall(temp_dir)
#    1509 with open(temp_name+'.json', 'r') as f:
#
# File ~/anaconda3/envs/torch/lib/python3.12/zipfile/__init__.py:1321, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1319 while True:
#    1320     try:
# -> 1321         self.fp = io.open(file, filemode)
#    1322     except OSError:
#    1323         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/0920_two_layer_model_non-ori_CNN_L4_10lag+1.ndn'

# %%
LL = cnn.eval_models(data, data_inds=data.val_blks, device=device, batch_size=3, null_adjusted=True)
print('Log Likelyhood shape', LL.shape)
# Out:
# Eval models: 100%|██████████████████████████████| 34/34 [00:08<00:00,  4.16it/s]
# Log Likelyhood shape (1491,)

# %%
print('Mean LL:', np.mean(LL) , 'L4 Exc LL:', np.mean(LL[L4_exc_idx]), 'L4 Inh LL:', np.mean(LL[L4_inh_idx]), 'L23 Exc LL:', np.mean(LL[L23_exc_idx]), 'L23 Inh LL:', np.mean(LL[L23_inh_idx]))
ss()
plt.plot([0,NC],[0,0], 'k')
plt.plot(LL)
plt.title('Log Likelyhood w/ mean '+str(np.mean(LL)))
plt.xlim([0,NC])
plt.ylim([0,1])
plt.show()
# Out:
# Mean LL: 0.29392725 L4 Exc LL: 0.39164445 L4 Inh LL: 0.42624962 L23 Exc LL: 0.20431647 L23 Inh LL: 0.07098389

# %%
cnn.plot_filters()

# %%
filters1 = cnn.get_weights(ffnet_target=0,layer_target=1)
ei_mask_layer1 = deepcopy(cnn.networks[0].layers[1]._ei_mask).detach().cpu().numpy()
ei_mask_layer2 = deepcopy(cnn.networks[0].layers[2]._ei_mask).detach().cpu().numpy()
ei_mask_layer3 = deepcopy(cnn.networks[0].layers[3]._ei_mask).detach().cpu().numpy()
print(filters1.shape)
print(ei_mask_layer1.shape)
print(ei_mask_layer2.shape)
print(ei_mask_layer3.shape)
# Out:
# (2, 19, 19, 14)
# (14,)
# (20,)
# (10,)

# %%
ss(4,4)
for i in range(16):
    plt.subplot(4,4,i+1)
    imagesc(filters1[0,:,:,i])
    plt.title('filter '+str(i)+' ei_mask '+str(ei_mask_layer1[i]))    
plt.tight_layout()
#plt.savefig('/home/ifernand/Desktop/filters.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 4
#       2 for i in range(16):
#       3     plt.subplot(4,4,i+1)
# ----> 4     imagesc(filters1[0,:,:,i])
#       5     plt.title('filter '+str(i)+' ei_mask '+str(ei_mask_layer1[i]))
#       6 plt.tight_layout()
#
# IndexError: index 14 is out of bounds for axis 3 with size 14

# %%
# Readout Weights (i.e. Barcodes)
full_ei_mask = np.concatenate((ei_mask_layer1, ei_mask_layer2, ei_mask_layer3))
readout_w = cnn.get_weights(ffnet_target=1)
print(readout_w.shape)
print(full_ei_mask.shape)
# Out:
# (44, 1491)
# (44,)

# %%
ss(rh=4)
imagesc((readout_w*full_ei_mask.reshape(full_ei_mask.shape[0],1)).T, cmap='bwr')
plt.axhline(y=ei_mask_layer1.shape[0]-0.5, color='black', lw=1)
plt.title('Computational Barcode')
plt.ylabel('Network Unit')
plt.xlabel('Neuron')
plt.colorbar()

# %%
weight_sum = np.sum(readout_w, axis=1)/np.std(readout_w, axis=1)
print(weight_sum.shape)
# Out:
# (32,)

# %%
ss()
plt.plot(weight_sum)
plt.title('Sum over readout weights')
plt.xlabel('Network Unit')
# Out:
# Text(0.5, 3.722222222222216, 'Network Unit')

# %% [markdown]
# ## Copy network to continue training

# %%
cnn2 = deepcopy(cnn)

# %%
mask2 = torch.ones(cnn2.get_weights(ffnet_target=0,layer_target=2).shape, dtype=torch.float32)
cnn2.networks[0].layers[2].mask = mask2.reshape(cnn2.networks[0].layers[2].weight.data.shape)

# %%
cnn2.fit(data, **adam_pars, verbose=2)
# Out:
# Model: M491_CsCX_R
#
# GPU Available: True, GPU Used: True
# Epoch 1: 100%|██████████| 136/136 [01:04<00:00,  2.10it/s, train_loss=24.747375]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.48it/s, val_loss=0.324838]
# Epoch 2: 100%|██████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.564019]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.46it/s, val_loss=0.307556]
# Epoch 3: 100%|██████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.547792]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.44it/s, val_loss=0.305717]
# Epoch 4: 100%|██████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.543543]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.43it/s, val_loss=0.305258]
# Epoch 5: 100%|██████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.542406]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.48it/s, val_loss=0.305134]
# Epoch 6: 100%|██████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.541618]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.43it/s, val_loss=0.30525]
# Epoch 7: 100%|██████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.541031]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.45it/s, val_loss=0.307034]
# Epoch 8: 100%|██████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.540672]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.46it/s, val_loss=0.303552]
# Epoch 9: 100%|██████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.540506]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.48it/s, val_loss=0.302576]
# Epoch 10: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.541063]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.41it/s, val_loss=0.30343]
# Epoch 11: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.539996]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.302427]
# Epoch 12: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.539887]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.43it/s, val_loss=0.303483]
# Epoch 13: 100%|█████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.539772]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.42it/s, val_loss=0.30278]
# Epoch 14: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.539666]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.45it/s, val_loss=0.302949]
# Epoch 15: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.539275]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.43it/s, val_loss=0.302112]
# Epoch 16: 100%|█████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.539185]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.42it/s, val_loss=0.301777]
# Epoch 17: 100%|█████████| 136/136 [01:05<00:00,  2.09it/s, train_loss=24.538811]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.302525]
# Epoch 18: 100%|██████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.53884]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.38it/s, val_loss=0.301853]
# Epoch 19: 100%|█████████| 136/136 [01:05<00:00,  2.06it/s, train_loss=24.538367]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.38it/s, val_loss=0.301417]
# Epoch 20: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.538539]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.40it/s, val_loss=0.301994]
# Epoch 21: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.538144]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.36it/s, val_loss=0.30178]
# Epoch 22: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.538114]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.301151]
# Epoch 23: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.538249]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.41it/s, val_loss=0.302133]
# Epoch 24: 100%|██████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.53784]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.43it/s, val_loss=0.299926]
# Epoch 25: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537786]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.300611]
# Epoch 26: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.538132]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.302891]
# Epoch 27: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537739]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.300605]
# Epoch 28: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537747]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.36it/s, val_loss=0.300825]
# Epoch 29: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537783]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.35it/s, val_loss=0.301737]
# Epoch 30: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537548]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.38it/s, val_loss=0.299787]
# Epoch 31: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537622]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.40it/s, val_loss=0.300824]
# Epoch 32: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537686]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.34it/s, val_loss=0.301689]
# Epoch 33: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537325]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.300076]
# Epoch 34: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537406]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.300238]
# Epoch 35: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537419]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.29979]
# Epoch 36: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537464]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.299679]
# Epoch 37: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537242]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.36it/s, val_loss=0.299821]
# Epoch 38: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537675]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.44it/s, val_loss=0.300611]
# Epoch 39: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537506]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.41it/s, val_loss=0.299515]
# Epoch 40: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537159]
# Validating ver=4: 100%|███████| 34/34 [00:06<00:00,  5.38it/s, val_loss=0.30059]
# Epoch 41: 100%|██████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.53711]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.36it/s, val_loss=0.299874]
# Epoch 42: 100%|█████████| 136/136 [01:05<00:00,  2.07it/s, train_loss=24.537419]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.299771]
# Epoch 43: 100%|███████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.5371]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.302019]
# Epoch 44: 100%|█████████| 136/136 [01:05<00:00,  2.06it/s, train_loss=24.537259]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.37it/s, val_loss=0.300487]
# Epoch 45: 100%|█████████| 136/136 [01:05<00:00,  2.08it/s, train_loss=24.537265]
# Validating ver=4: 100%|██████| 34/34 [00:06<00:00,  5.39it/s, val_loss=0.301106]
# Early stopping
# Done fitting
#   Fit complete: 3232.9085037708282 sec elapsed

# %%
cnn2.save_model_zip('models/0926_three_layer_model_non-ori_CNN_V1_no_timemask.ndn')
# Out:
#   Model saved:  models/0926_three_layer_model_non-ori_CNN_V1_no_timemask.ndn

# %%
LL2 = cnn2.eval_models(data, data_inds=data.val_blks, device=device, batch_size=2, null_adjusted=True)
print('Log Likelyhood shape', LL2.shape)
# Out:
# Eval models: 100%|██████████████████████████████| 51/51 [00:05<00:00,  8.65it/s]
# Log Likelyhood shape (1491,)

# %%
ss()
plt.plot([0,NC],[0,0], 'k')
plt.plot(LL, label='mask')
plt.plot(LL2, label='no mask')
plt.title('Log Likelyhood w/ mean '+str(np.mean(LL))+' to '+str(np.mean(LL2)))
plt.xlim([0,NC])
plt.ylim([0,1])
plt.legend()
plt.show()

# %%
cnn2_filters1 = cnn2.get_weights(ffnet_target=0,layer_target=1)
cnn2_ei_mask_layer1 = deepcopy(cnn2.networks[0].layers[1]._ei_mask).detach().cpu().numpy()
cnn2_ei_mask_layer2 = deepcopy(cnn2.networks[0].layers[2]._ei_mask).detach().cpu().numpy()
print(cnn2_filters1.shape)
print(cnn2_ei_mask_layer1.shape)
print(cnn2_ei_mask_layer2.shape)
# Out:
# (2, 19, 19, 16)
# (16,)
# (16,)

# %%
ss(4,4)
for i in range(16):
    plt.subplot(4,4,i+1)
    imagesc(cnn2_filters1[0,:,:,i])
    plt.title('filter '+str(i)+' ei_mask '+str(cnn2_ei_mask_layer1[i]))    
plt.tight_layout()
#plt.savefig('/home/ifernand/Desktop/filters.png')
plt.show()

# %%
# Readout Weights (i.e. Barcodes)
cnn2_full_ei_mask = np.concatenate((cnn2_ei_mask_layer1, cnn2_ei_mask_layer2))
cnn2_readout_w = cnn2.get_weights(ffnet_target=1)
print(cnn2_readout_w.shape)
print(cnn2_full_ei_mask.shape)
# Out:
# (32, 1491)
# (32,)

# %%
ss(rh=4)
imagesc((cnn2_readout_w*cnn2_full_ei_mask.reshape(cnn2_full_ei_mask.shape[0],1)).T, cmap='bwr')
plt.axhline(y=cnn2_ei_mask_layer1.shape[0]-0.5, color='black', lw=1)
plt.title('Computational Barcode')
plt.ylabel('Network Unit')
plt.xlabel('Neuron')
plt.colorbar()

# %%
cnn2_weight_sum = np.sum(cnn2_readout_w, axis=1)
print(cnn2_weight_sum.shape)
# Out:
# (32,)

# %%
ss()
plt.plot(weight_sum, label='mask')
plt.plot(cnn2_weight_sum, label='no mask')
plt.title('Sum over readout weights')
plt.xlabel('Network Unit')
plt.legend()

# %%
cnn2_filt_count = np.sum(cnn2_readout_w > 0.001, axis=0)
cnn2_filt_count.shape
# Out:
# (1491,)

# %%
ss()
plt.bar(np.arange(NC),cnn2_filt_count)
# Out:
# <BarContainer object of 1491 artists>
